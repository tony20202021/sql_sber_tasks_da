# %% [markdown]
# # REBOOT_DA
# ## 11_homework_without_pandas
# ### Михалев Антон

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lyDLAutA88s', width=800, height=300)

# %%
# 1. Посмотрите видео Дэвида Бизли про всроенные инструменты Python
# 2. Попробуйте используя встроенные инструменты Python проанизировать таблицу из файла "Vacancy.csv"
# 3. Попробуйте ответить на вопросы:
# Сколько вакансий, которые вам нравятся?
# Насколько свежие эти вакансии?
# Сколько вакансий с позициями на которых вы работаете?
# Сколько вакансий для аналатика данных?
# Сколько вакансий для аналитика данных с использованием Python?

# В задании важно не использовать pandas и numpy, а встроенные инструменты python
# Counter, CSV, defaultdict, sorted

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "./drive/MyDrive/Colab Notebooks/20_REBOOT_DA/"
# Out:
# 11_homeword_without_pandas.ipynb  lesson4.ipynb      lesson_9_homework
# avocado.csv			  lesson_5_homework  ships_202202282111.csv
# lesson_2_homework		  lesson_6_homework  vacancy.csv
# lesson_3_homework		  lesson_7_homework
# lesson_4_homework		  lesson_8_homework

# %%
colab_path = "./drive/MyDrive/Colab Notebooks/20_REBOOT_DA/"
colab_path
# Out:
# './drive/MyDrive/Colab Notebooks/20_REBOOT_DA/'

# %%
import csv

# %%
import sys

# %%
csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
vacs = list(csv.DictReader(open(colab_path + 'vacancy.csv')))

len(vacs)
# Out:
# 4002

# %%
vacs[0]
# Out:
# OrderedDict([('id', '383479'),
#              ('created_at', '2021-03-14 09:39:21.854462'),
#              ('updated_at', '2021-03-14 09:39:21.854584'),
#              ('vacid', '1474941'),
#              ('vactitle', 'Senior java-разработчик (в команду Онбординга)'),
#              ('vacdescription',
#               ' Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка. Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.'),
#              ('vacdate', '2021-03-15'),
#              ('vacstatus', 'new'),
#              ('vaclink',
#               'https://my.sbertalents.ru/#/job-requisition/1474941'),
#              ('vachtml',
#               '{"title": "Senior java-\\u0440\\u0430\\u0437\\u0440\\u0430\\u0431\\u043e\\u0442\\u0447\\u0438\\u043a (\\u0432 \\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0443 \\u041e\\u043d\\u0431\\u043e\\u0440\\u0434\\u0438\\u043d\\u0433\\u0430)", "footer": "<p class=\\"1\\">&nbsp;</p><p class=\\"1\\"><strong><span style=\\"font-size:14px\\"><span lang=\\"ru\\"><span style=\\"background:white\\">\\u0420\\u0430\\u0431\\u043e\\u0442\\u0430 \\u0443 \\u043d\\u0430\\u0441 &mdash; \\u044d\\u0442\\u043e:</span></span></span></strong></p><ul><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0430 \\u043f\\u0440\\u043e\\u0444\\u0435\\u0441\\u0441\\u0438\\u043e\\u043d\\u0430\\u043b\\u043e\\u0432, \\u0433\\u043e\\u0442\\u043e\\u0432\\u044b\\u0445 \\u043f\\u043e\\u0434\\u0434\\u0435\\u0440\\u0436\\u0430\\u0442\\u044c \\u0432\\u0430\\u0448\\u0438 \\u0438\\u043d\\u0438\\u0446\\u0438\\u0430\\u0442\\u0438\\u0432\\u044b;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043c\\u043e\\u0449\\u043d\\u043e\\u0435 \\u0436\\u0435\\u043b\\u0435\\u0437\\u043e, \\u0434\\u043e\\u043f\\u043e\\u043b\\u043d\\u0438\\u0442\\u0435\\u043b\\u044c\\u043d\\u044b\\u0435 \\u043c\\u043e\\u043d\\u0438\\u0442\\u043e\\u0440\\u044b \\u0438 \\u0432\\u0441\\u0451, \\u0447\\u0442\\u043e \\u043d\\u0443\\u0436\\u043d\\u043e \\u0434\\u043b\\u044f \\u043f\\u0440\\u043e\\u0434\\u0443\\u043a\\u0442\\u0438\\u0432\\u043d\\u043e\\u0439 \\u0440\\u0430\\u0431\\u043e\\u0442\\u044b;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043e\\u0431\\u0443\\u0447\\u0435\\u043d\\u0438\\u0435 \\u0437\\u0430 \\u0441\\u0447\\u0451\\u0442 \\u043a\\u043e\\u043c\\u043f\\u0430\\u043d\\u0438\\u0438;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u0433\\u0438\\u0431\\u043a\\u0438\\u0439 \\u0433\\u0440\\u0430\\u0444\\u0438\\u043a</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043a\\u0440\\u0430\\u0441\\u0438\\u0432\\u044b\\u0439 \\u0438 \\u043a\\u043e\\u043c\\u0444\\u043e\\u0440\\u0442\\u043d\\u044b\\u0439 \\u043e\\u0444\\u0438\\u0441&nbsp;&nbsp;</span></span><span style=\\"font-size:10.5pt\\">\\u0433. \\u0421\\u0430\\u043d\\u043a\\u0442-\\u041f\\u0435\\u0442\\u0435\\u0440\\u0431\\u0443\\u0440\\u0433, </span><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043c. \\u041b\\u0430\\u0434\\u043e\\u0436\\u0441\\u043a\\u0430\\u044f&nbsp;&nbsp;</span></span><span style=\\"font-size:10.5pt\\">\\u043f\\u043b. \\u041a\\u0430\\u0440\\u043b\\u0430 \\u0424\\u0430\\u0431\\u0435\\u0440\\u0436\\u0435 8 \\u0412</span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u0414\\u041c\\u0421;</span></span></li><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043f\\u0440\\u043e\\u0437\\u0440\\u0430\\u0447\\u043d\\u0430\\u044f \\u0441\\u0438\\u0441\\u0442\\u0435\\u043c\\u0430 \\u0431\\u043e\\u043d\\u0443\\u0441\\u043e\\u0432 \\u0438 \\u043f\\u0440\\u0435\\u043c\\u0438\\u0439, \\u0434\\u043e\\u0441\\u0442\\u043e\\u0439\\u043d\\u0430\\u044f \\u0437\\u0430\\u0440\\u043f\\u043b\\u0430\\u0442\\u0430 &mdash; \\u0440\\u0430\\u0437\\u043c\\u0435\\u0440 \\u043e\\u0431\\u0441\\u0443\\u0434\\u0438\\u043c \\u043d\\u0430 \\u0441\\u043e\\u0431\\u0435\\u0441\\u0435\\u0434\\u043e\\u0432\\u0430\\u043d\\u0438\\u0438.</span></span></li></ul>", "header": "<p class=\\"1\\"><span style=\\"font-size:14px\\"><strong><span style=\\"background:white\\">\\u0418\\u043d\\u0444\\u043e\\u0440\\u043c\\u0430\\u0446\\u0438\\u044f </span><span lang=\\"ru\\" style=\\"background:white\\">\\u043e \\u043f\\u0440\\u043e\\u0435\\u0 ...

# %% [markdown]
# # Сколько вакансий, которые вам нравятся?
# * допустим, мне нравятся вакансии, в названии которых есть слово "senior" :)

# %%
result = [v for v in vacs if ('Senior'.upper() in v['vactitle'].upper())]
len(result), result[:2]
# Out:
# (133,
#  [OrderedDict([('id', '383479'),
#                ('created_at', '2021-03-14 09:39:21.854462'),
#                ('updated_at', '2021-03-14 09:39:21.854584'),
#                ('vacid', '1474941'),
#                ('vactitle', 'Senior java-разработчик (в команду Онбординга)'),
#                ('vacdescription',
#                 ' Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка.Информация о проекте:Наша команда делает новые экспериментальные фичи для СБОЛа.Сейчас мы разрабатываем систему, с помощью которой разные команды Сбера смогут создавать квесты для мобильного приложения.Также мы будем разрабатывать внутреннюю платформу для продуктовых экспериментов. Описание команды:2-pizza team: сейчас у нас работают разработчики iOS и Android, продакт и аналитик. К команде в ближайшее время подключится тестировщик и еще один аналитик. Мы ожидаем, что Вы:Работали раннее в продуктовой agile-команде;Имеете опыт работы больше 4 лет с Java и ее экосистемой;Владеете Spring: Core, MVC, Boot, Cloud;Работали с реляционными БД;Трепетно относитесь к тестовому покрытию;Будете относиться с заботой к нашим пользователям, продукту и команде. Будет здорово, если вы:Умеете готовить ansible;Работали с k8s;Использовали kafka;Умеете оптимизировать SQL-запросы. Вам предстоит:отвечать за качество технических решений;придумывать реализацию для безумных идей наших продактов;разрабатывать сервисы, интегрироваться с множеством систем банка. Работа у нас — это:команда профессионалов, готовых поддержать ваши инициативы;мощное железо, дополнительные мониторы и всё, что нужно для продуктивной работы;обучение за счёт компании;гибкий графиккрасивый и комфортный офис  г. Санкт-Петербург, м. Ладожская  пл. Карла Фаберже 8 ВДМС;прозрачная система бонусов и премий, достойная зарплата — размер обсудим на собеседовании.'),
#                ('vacdate', '2021-03-15'),
#                ('vacstatus', 'new'),
#                ('vaclink',
#                 'https://my.sbertalents.ru/#/job-requisition/1474941'),
#                ('vachtml',
#                 '{"title": "Senior java-\\u0440\\u0430\\u0437\\u0440\\u0430\\u0431\\u043e\\u0442\\u0447\\u0438\\u043a (\\u0432 \\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0443 \\u041e\\u043d\\u0431\\u043e\\u0440\\u0434\\u0438\\u043d\\u0433\\u0430)", "footer": "<p class=\\"1\\">&nbsp;</p><p class=\\"1\\"><strong><span style=\\"font-size:14px\\"><span lang=\\"ru\\"><span style=\\"background:white\\">\\u0420\\u0430\\u0431\\u043e\\u0442\\u0430 \\u0443 \\u043d\\u0430\\u0441 &mdash; \\u044d\\u0442\\u043e:</span></span></span></strong></p><ul><li class=\\"1\\"><span lang=\\"ru\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\">\\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u
#   OrderedDict([('id', '383598'),
#                ('created_at', '2021-03-14 09:39:21.854462'),
#                ('updated_at', '2021-03-14 09:39:21.854584'),
#                ('vacid', '1564008'),
#                ('vactitle', 'Senior Java Developer'),
#                ('vacdescription',
#                 'HR-платформа Сбера - это многофункциональная система для решения всех задач, связанных с управлением человеческими ресурсами.Мы разработали приложение HR-платформы с нуля (no legacy) и продолжаем активно его развивать.Нашим приложением ежедневно будут пользоваться большая часть из 270тыс сотрудников компании, а также кандидаты и рекрутинговые агентства.С нами уже работает большая команда профессионалов: разработчики backend (java/Kotlin), frontend (js/React) и mobile (swift, ReactNative), UX/UI дизайнеры, QA, инженеры devops, SRE, DS и т.д. Стек проекта:Java 8 / 11, Hibernate, Spring;Kotlin;SQL и NoSQL базы данных;Linux;Docker, OpenShift и т.д. Задачи над которыми предстоит работать:Проектирование и разработка ПО приложений;Написание автотестов, исправление багов, участие в ревью кода;Взаимодействие с разработчиками, дизайнерами и другими командами в формате Agile. Наши ожидания от кандидатов:Опыт работы с Java от 4 лет;Опыт работы со Spring Framework;Знание SQL и NoSQL баз данных;Опыт работы с Junit, Spring Test, Mockito. Будет плюсом опыт работы с:Hibernate;Linux;Docker, OpenShift;Maven, Jira, Bitbucket. Мы предлагаем:Хороший офис рядом со станцией метро Кутузовская со всеми удобствами (столовые + множество кафе + кухни с холодильниками, кофемашинами и т.п.; бесплатный спортзал, места для отдыха, бесплатная подземная парковка;Достойная заработная плата (оклад + премии);Возможность работать с современным стеком технологий;Оформление по ТК РФ;Социальный пакет (ДМС);Огромный каталог образовательных программ, возможность обучения и сертификации за счет компании;Программа льготного кредитования в Сбере;Дисконт-программы от множества компаний-партнеров.HR-платформа Сбера - это многофункциональная система для решения всех задач, связанных с управлением человеческими ресурсами.Мы разработали приложение HR-платформы с нуля (no legacy) и продолжаем активно его развивать.Нашим приложением ежедневно будут пользоваться большая часть из 270тыс сотрудников компании, а также кандидаты и рекрутинговые агентства.С нами уже работает большая команда профессионалов: разработчики backend (java/Kotlin), frontend (js/React) и mobile (swift, ReactNative), UX/UI дизайнеры, QA, инженеры devops, SRE, DS и т.д. Стек проекта:Java 8 / 11, Hibernate, Spring;Kotlin;SQL и NoSQL базы данных;Linux;Docker, OpenShift и т.д. Задачи над которыми предстоит работать:Проектирование и разработка ПО приложений;Написание автотестов, исправление багов, участие в ревью кода;Взаимодействие с разработчиками, дизайнерами и другими командами в формате Agile. Наши ожидания от кандидатов:Опыт работы с Java от 4 лет;Опыт работы со Spring Framework;Знание SQL и NoSQL баз данных;Опыт работы с Junit, Spring Test, Mockito. Будет плюсом опыт работы с:Hibernate;Linux;Docker, OpenShift;Maven, Jira, Bitbucket. М
# %% [markdown]
# # Насколько свежие эти вакансии?

# %%
from datetime import datetime

[(datetime.now() - datetime.strptime(v['vacdate'], '%Y-%m-%d')).days for v in result][:2]
# Out:
# [377, 377]

# %% [markdown]
# # Сколько вакансий с позициями на которых вы работаете?
# * допустим, я работаю программистом на Дельфи :)

# %%
result = [v 
          for v in vacs 
          if (('delphi'.upper() in v['vactitle'].upper())) 
            or (('delphi'.upper() in v['vacdescription'].upper()))
          ]
len(result), result[:2]
# Out:
# (1,
#  [OrderedDict([('id', '384990'),
#                ('created_at', '2021-03-14 09:39:21.854462'),
#                ('updated_at', '2021-03-14 09:39:21.854584'),
#                ('vacid', '1338763'),
#                ('vactitle', 'Разработчик PL/SQL'),
#                ('vacdescription',
#                 'Что мы предлагаем:∙ Высокую з/пл. (обсуждается индивидуально с каждым кандидатом)∙ Оформление по ТК РФ, полный соц. пакет∙ Интересные и амбициозные задачи∙ Дружная команда∙ Позитивная атмосфераПроект: Команда занимается развитием продуктов расчетов Транзакционного Бизнеса Банка (исполнению платежных распоряжений и зачислению средств на расчетные счета по договорам РКО ЮЛ, исполнением входящих и исходящих инкассовых поручений и платежных требований, управлением документами, поставленными в картотеке.Что надо делать:∙ разрабатывать бизнес-логику на PL/SQL∙ дорабатывать и оптимизировать существующие объекты (Oracle) на PL/SQL∙ создавать собственные объектыЧто требуется от Вас:∙ опыт разработки на PL/SQL от 1 года; ∙ отличное знание SQL и PL/ SQL∙ понимание основ архитектуры Oracle∙ владение навыками разработки оптимального кода и оптимизации запросов∙ знание основ ООП, минимальный опыт программирования на высокоуровневых языках, Java приветствуется.Приветствуется (но не обязательно):∙ опыт программирования на каком-либо из высокоуровневых языков (Delphi, .NET, Java, PHP)∙ опыт интеграции c другими СУБД (MSSQL)∙ опыт работы с системами контроля версий (SVN)Проект: Команда занимается развитием продуктов расчетов Транзакционного Бизнеса Банка (исполнению платежных распоряжений и зачислению средств на расчетные счета по договорам РКО ЮЛ, исполнением входящих и исходящих инкассовых поручений и платежных требований, управлением документами, поставленными в картотеке.Что надо делать:∙ разрабатывать бизнес-логику на PL/SQL∙ дорабатывать и оптимизировать существующие объекты (Oracle) на PL/SQL∙ создавать собственные объектыЧто требуется от Вас:∙ опыт разработки на PL/SQL от 1 года; ∙ отличное знание SQL и PL/ SQL∙ понимание основ архитектуры Oracle∙ владение навыками разработки оптимального кода и оптимизации запросов∙ знание основ ООП, минимальный опыт программирования на высокоуровневых языках, Java приветствуется.Приветствуется (но не обязательно):∙ опыт программирования на каком-либо из высокоуровневых языков (Delphi, .NET, Java, PHP)∙ опыт интеграции c другими СУБД (MSSQL)∙ опыт работы с системами контроля версий (SVN)Что мы предлагаем:∙ Высокую з/пл. (обсуждается индивидуально с каждым кандидатом)∙ Оформление по ТК РФ, полный соц. пакет∙ Интересные и амбициозные задачи∙ Дружная команда∙ Позитивная атмосфера'),
#                ('vacdate', '2021-02-27'),
#                ('vacstatus', 'new'),
#                ('vaclink',
#                 'https://my.sbertalents.ru/#/job-requisition/1338763'),
#                ('vachtml',
#                 '{"title": "\\u0420\\u0430\\u0437\\u0440\\u0430\\u0431\\u043e\\u0442\\u0447\\u0438\\u043a PL/SQL", "footer": "<p><span style=\\"font-size:12pt\\"><span style=\\"background:white\\"><span style=\\"font-family:Calibri,sans-serif\\"><strong><em><span style=\\"border:none windowtext 1.0pt; font-size:10.5pt; padding:0cm\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">\\u0427\\u0442\\u043e \\u043c\\u044b \\u043f\\u0440\\u0435\\u0434\\u043b\\u0430\\u0433\\u0430\\u0435\\u043c:</span></span></span></em></strong></span></span></span></p><p><span style=\\"font-size:12pt\\"><span style=\\"background:white\\"><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"border:none windowtext 1.0pt; font-size:10.5pt; padding:0cm\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">\\u2219 \\u0412\\u044b\\u0441\\u043e\\u043a\\u0443\\u044e \\u0437/\\u043f\\u043b. (\\u043e\\u0431\\u0441\\u0443\\u0436\\u0434\\u0430\\u0435\\u0442\\u0441\\u044f \\u0438\\u043d\\u0434\\u0438\\u0432\\u0438\\u0434\\u0443\\u0430\\u043b\\u044c\\u043d\\u043e \\u0441 \\u043a\\u0430\\u0436\\u0434\\u044b\\u043c \\u043a\\u0430\\u043d\\u0434\\u0438\\u0434\\u0430\\u0442\\u043e\\u043c)</span></span></span></span></span></span></p><p><span style=\\"font-size:12pt\\"><span style=\\"background:white\\"><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"border:none windowtext 1.0pt; font-size:10.5pt; padding:0cm\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">\\u2219 \\u041e\\u0444\\u043e\\u0440\\u043c\\u043b\\u0435\\u043d\\u0438\\u0435 \\u043f\\u043e \\u0422\\u041a \\u0420\\u0424, \\u043f\\u043e\\u043b\\u043d\\u044b\\u0439 \\u0441\\u043e\\u0446. \\u043f\\u0430\\u043a\\u0435\\u0442</span></span></span></span></span></span></p><p><span style=\\"font-size:12pt\\"><span style=\\"background:white\\"><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"border:none windowtext 1.0pt; font-size:10.5pt; padding:0cm\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">\\u2219 \\u0418\\u043d\\u0442\\u0435\\u0440\\u0435\\u0441\\u043d\\u044b\\u0435 \\u0438 \\u0430\\u043c\\u0431\\u0438\\u0446\\u0438\\u043e\\u0437\\u043d\\u044b\\u0435 \\u0437\\u0430\\u0434\\u0430\\u0447\\u0438</span></span></span></span></span></span></p><p><span style=\\"font-size:12pt\\"><span style=\\"background:white\\"><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"border:none windowtext 1.0pt; font-size:10.5pt; padding:0cm\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">\\u2219 \\u0414\\u0440\\u0443\\u0436\\u043d\\u0430\\u044f \\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0430</span></span></span></span></span></span></p><p><span style=\\"font-size:12pt\\"><span style=\\"background:white\\"><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"border:none windowtext 1.0pt; font-size:10.5pt; padding:0cm\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">\\u2219 \\u041f\\u043e\\u0437\\u0438\\u0442\\u0438\\u0432\\u043d\\u0430\\u044f \\u0430\\u0442\\u043c\\u043e\\u0441\\u0444\\u0435\\u0440\\u0430</span></span></span></span></span></span></p>", "header": "<p><span style=\\"font-family:Arial,Helvetica,sans-serif\\"><span style=\\"font-size:14px\\"><em><strong>\\u041f\\u0440\\u043e\\u0435\\u043a\\u0442:</strong> </em>\\u041a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0430 \\u0437\\u0430\\u043d\\u0438\\u043c\\u0430\\u0435\\u0442\\u0441\\u044f \\u0440\\u0430\\u0437\\u0432\\u0438\\u0442\\u0438\\u0435\\u043c \\u043f\\u0440\\u043e\\u0434\\u0443\\u043a\\u0442\\u043e\\u0432 \\u0440\\u0430\\u0441\\u0447\\u0435\\u0442\\u043e\\u0432 \\u0422\\u0440\\u0430\\u043d\\u0437\\u0430\\u043a\\u0446\\u0438\\u043e\\u043d\\u043d\\u043e\\u0433\\u043e \\u0411\\u0438\\u0437\\u043d\\u0435\\u0441\\u0430 \\u0411\\u0430\\u043d\\u043a\\u043 ...

# %%
len(result[0]['vacdescription'])
# Out:
# 2342

# %%
pos = (result[0]['vacdescription'].upper()).find('delphi'.upper())
pos
# Out:
# 1060

# %%
result[0]['vacdescription'][pos - 50: pos + 50]
# Out:
# 'ирования на каком-либо из высокоуровневых языков (Delphi, .NET, Java, PHP)∙ опыт интеграции c другим'

# %% [markdown]
# # Сколько вакансий для аналатика данных?

# %%
query = 'data analyst'

result = [v 
          for v in vacs 
          if ((query.upper() in v['vactitle'].upper())) 
            # or ((query.upper() in v['vacdescription'].upper()))
          ]
len(result), result[:2]
# Out:
# (22,
#  [OrderedDict([('id', '383700'),
#                ('created_at', '2021-03-14 09:39:21.854462'),
#                ('updated_at', '2021-03-14 09:39:21.854584'),
#                ('vacid', '1571444'),
#                ('vactitle',
#                 'Data analyst. Аналитик данных в трайб «Массовая персонализация».'),
#                ('vacdescription',
#                 'Обязанности:- анализ данных по процессам взаимодействия с клиентами Банка, эффективности кампаний продаж, достижению бизнес-показателей (средствами Teradata (SQL), Python, в перспективе - Hive, Impala, Spark)- подготовка презентаций в PowerPoint- поиск целевой аудитории для продвижения продуктов и сервисов Банка, выстраивание алгоритмов приоритизации предложений- разработка аналитической отчетности- построение и проверка бизнес-гипотез- визуализация данных, в том числе с использованием специализированных BI-инструментов (Qlik View)Требования к кандидатам:- высшее образование по направлению: прикладная математика/физика/ИТ/финансы- желателен опыт работы в банковской сфере, понимание внутрибанковских процессов и    знание банковских продуктов и услуг- отличное знание Excel (VBA будет являться преимуществом)- владение методами анализа данных и инструментами подготовки отчетности- опыт работы с базами данных, навыки написания сложных SQL-запросов (Teradata, Oracle, SAS, MS SQL)- опыт работы с инструментами визуализации данных является преимуществом (в идеале - Qlik View)- знание Python является преимуществомЧто мы предлагаем:- стабильную работу в высокопрофессиональной среде;- карьерный путь в головном офисе международной организации;- ДМС, фитнес-центр;- корпоративное обучение, курсы и тренинги;- современный офис (5 минут пешком от метро Кутузовская и МЦК), признанный лучшим среди новых офисов российских компаний в 2017 году- анализ данных по процессам взаимодействия с клиентами Банка, эффективности кампаний продаж, достижению бизнес-показателей (средствами Teradata (SQL), Python, в перспективе - Hive, Impala, Spark)- подготовка презентаций в PowerPoint- поиск целевой аудитории для продвижения продуктов и сервисов Банка, выстраивание алгоритмов приоритизации предложений- разработка аналитической отчетности- построение и проверка бизнес-гипотез- визуализация данных, в том числе с использованием специализированных BI-инструментов (Qlik View)Требования к кандидатам:- высшее образование по направлению: прикладная математика/физика/ИТ/финансы- желателен опыт работы в банковской сфере, понимание внутрибанковских процессов и    знание банковских продуктов и услуг- отличное знание Excel (VBA будет являться преимуществом)- владение методами анализа данных и инструментами подготовки отчетности- опыт работы с базами данных, навыки написания сложных SQL-запросов (Teradata, Oracle, SAS, MS SQL)- опыт работы с инструментами визуализации данных является преимуществом (в идеале - Qlik View)- знание Python является преимуществомЧто мы предлагаем:- стабильную работу в высокопрофессиональной среде;- карьерный путь в головном офисе международной организации;- ДМС, фитнес-центр;- корпоративное обучение, курсы и тренинги;- современный офис (5 минут пешком от метро Кутузовская и МЦК), признанный лучшим среди новых офисов российских компаний в 2017 году'),
#                ('vacdate', '2021-03-12'),
#                ('vacstatus', 'new'),
#                ('vaclink',
#                 'https://my.sbertalents.ru/#/job-requisition/1571444'),
#                ('vachtml',
#                 '{"title": "Data analyst. \\u0410\\u043d\\u0430\\u043b\\u0438\\u0442\\u0438\\u043a \\u0434\\u0430\\u043d\\u043d\\u044b\\u0445 \\u0432 \\u0442\\u0440\\u0430\\u0439\\u0431 \\u00ab\\u041c\\u0430\\u0441\\u0441\\u043e\\u0432\\u0430\\u044f \\u043f\\u0435\\u0440\\u0441\\u043e\\u043d\\u0430\\u043b\\u0438\\u0437\\u0430\\u0446\\u0438\\u044f\\u00bb.", "header": "<p><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><strong><span style=\\"border:none windowtext 1.0pt; font-size:10.5pt; padding:0cm\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">\\u041e\\u0431\\u044f\\u0437\\u0430\\u043d\\u043d\\u043e\\u0441\\u0442\\u0438:</span></span></span></strong></span></span></span></p><p><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:10.5pt\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">- \\u0430\\u043d\\u0430\\u043b\\u0438\\u0437 \\u0434\\u0430\\u043d\\u043d\\u044b\\u0445 \\u043f\\u043e \\u043f\\u0440\\u043e\\u0446\\u0435\\u0441\\u0441\\u0430\\u043c \\u0432\\u0437\\u0430\\u0438\\u043c\\u043e\\u0434\\u0435\\u0439\\u0441\\u0442\\u0432\\u0438\\u044f \\u0441 \\u043a\\u043b\\u0438\\u0435\\u043d\\u0442\\u0430\\u043c\\u0438 \\u0411\\u0430\\u043d\\u043a\\u0430, \\u044d\\u0444\\u0444\\u0435\\u043a\\u0442\\u0438\\u0432\\u043d\\u043e\\u0441\\u0442\\u0438 \\u043a\\u0430\\u043c\\u043f\\u0430\\u043d\\u0438\\u0439 \\u043f\\u0440\\u043e\\u0434\\u0430\\u0436, \\u0434\\u043e\\u0441\\u0442\\u0438\\u0436\\u0435\\u043d\\u0438\\u044e \\u0431\\u0438\\u0437\\u043d\\u0435\\u0441-\\u043f\\u043e\\u043a\\u0430\\u0437\\u0430\\u0442\\u0435\\u043b\\u0435\\u0439 </span></span></span><span style=\\"font-size:10.5pt\\"><span style=\\"background:white\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">(\\u0441\\u0440\\u0435\\u0434\\u0441\\u0442\\u0432\\u0430\\u043c\\u0438 Teradata (</span></span></span></span><span lang=\\"EN-US\\" style=\\"font-size:10.5pt\\"><span style=\\"background:white\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">SQL</span></span></span></span><span style=\\"font-size:10.5pt\\"><span style=\\"background:white\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">), Python, \\u0432 \\u043f\\u0435\\u0440\\u0441\\u043f\\u0435\\u043a\\u0442\\u0438\\u0432\\u0435 - Hive, Impala, Spark)</span></span></span></span></span></span></span></p><p><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:10.5pt\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">- \\u043f\\u043e\\u0434\\u0433\\u043e\\u0442\\u043e\\u0432\\u043a\\u0430 \\u043f\\u0440\\u0435\\u0437\\u0435\\u043d\\u0442\\u0430\\u0446\\u0438\\u0439 \\u0432 PowerPoint</span></span></span></span></span></span></p><p><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:10.5pt\\"><span style=\\"font-family:&quot;Arial&quot;,sans-serif\\"><span style=\\"color:#333333\\">- \\u043f\\u043e\\u0438\\u0441\\u043a \\u0446\\u0435\\u043b\\u0435\\u0432\\u043e\\u0439 \\u0430\\u0443\\u0434\\u0438\\u0442\\u043e\\u0440\\u0438\\u0438 \\u0434\\u043b\\u044f \\u043f\\u0440\\u043e\\u0434\\u0432\\u0438\\u0436\\u0435\\u043d\\u0438\\u044f \\u043f\\u0440\\u043e\\u0434\\u0443\\u043a\\u0442\\u043e\\u0432 \\u0438 \\u0441\\u0435\\u0440\\u0432\\u0438\\u0441\\u043e\\u0432 \\u0411\\u0430\\u043d\\u043a\\u0430, \\u0432\\u044b\\u0441\\u0442\\u0440\\u0430\\u0438\\u0432\\u0430\\u043d\\u0438\\u0435 \\u0430\\u043b\\u0433\\u043e\\u0440\\u0438\\u0442\\u043c\\u043e\\u0432 \\u043f\\u0440\\u0438\\u043e\\u0440\\u0438\\u0442\\u0438\\u0437\\u0430\\u0446\\u0438\\u0438 \\u043f\\u0440\\u0435\\u0434\\u043b\\u043e\\u0436\\u0435\\u043d\\u0438\\u0439</span></span></span></spa ...
#   OrderedDict([('id', '384287'),
#                ('created_at', '2021-03-14 09:39:21.854462'),
#                ('updated_at', '2021-03-14 09:39:21.854584'),
#                ('vacid', '1533450'),
#                ('vactitle', 'Data Analyst в команду «Отчетность и аналитика»'),
#                ('vacdescription',
#                 'Условия:Конкурентоспособный уровень дохода (оклад+достойные премии);Молодая и дружная команда;Корпоративное обучение, курсы, тренинги;Уютный и комфортабельный офис рядом с м. Кутузовская: зоны отдыха, фитнес-центр, массажные кресла, подземная парковка;ДМС, страхование от несчастных случаев, социальные гарантии, корпоративные мероприятия.Команда реальных профессионалов, практиков рынка, приглашает в свою команду DA.У нас высокий ритм и быстрое принятие решений. Широкие полномочия и неограниченные возможности роста Построение отчетности по бизнес направлениям банка и подготовка аналитических исследованийОбязанности:Построение аналитических отчетов по ключевым показателям, проверка гипотез и аналитические исследования, ad-hoc аналитика;Работа с SQL (сбор, очистка и подготовка данных);Сегментация клиентской базы, построение сложных математических моделей, исследование зависимостей на большом объеме информации;Участие в разработке моделей.Требования:Высшее образование (математика/физика/программирование/финансы);Глубокое понимание теории вероятности и математической статистики;Умение работать с большим объемом данных;Умение проверять гипотезы с использование математических инструментов;Опыт работы с базами данных от 2-х лет (Teradata /MS SQL), навыки работы с массивами данных; Знание Excel на высоком уровне;Навыки работы с Python (numpy, scipy, pandas, statsmodels). Высшее образование (математика/физика/программирование/финансы);Глубокое понимание теории вероятности и математической статистики;Умение работать с большим объемом данных;Умение проверять гипотезы с использование математических инструментов;Опыт работы с базами данных от 2-х лет (Teradata /MS SQL), навыки работы с массивами данных; Знание Excel на высоком уровне;Навыки работы с Python (numpy, scipy, pandas, statsmodels). Команда реальных профессионалов, практиков рынка, приглашает в свою команду DA.У нас высокий ритм и быстрое принятие решений. Широкие полномочия и неограниченные возможности роста Построение отчетности по бизнес направлениям банка и подготовка аналитических исследованийПостроение аналитических отчетов по ключевым показателям, проверка гипотез и аналитические исследования, ad-hoc аналитика;Работа с SQL (сбор, очистка и подготовка данных);Сегментация клиентской базы, построение сложных математических моделей, исследование зависимостей на большом объеме информации;Участие в разработке моделей.Конкурентоспособный уровень дохода (оклад+достойные премии);Молодая и дружная команда;Корпоративное обучение, курсы, тренинги;Уютный и комфортабельный офис рядом с м. Кутузовская: зоны отдыха, фитнес-центр, массажные кресла, подземная парковка;ДМС, страхование от несчастных случаев, социальные гарантии, корпоративные мероприятия.'),
#                ('vacdate', '2021-03-05'),
#                ('vacstatus', 'new'),
#                ('vaclink',
#                 'https://my.sbertalents.ru/#/job-requisition/1533450'),
#                ('vachtml',
#                 '{"title": "Data Analyst \\u0432 \\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0443 \\u00ab\\u041e\\u0442\\u0447\\u0435\\u0442\\u043d\\u043e\\u0441\\u0442\\u044c \\u0438 \\u0430\\u043d\\u0430\\u043b\\u0438\\u0442\\u0438\\u043a\\u0430\\u00bb", "footer": "<p><span style=\\"font-size:11pt\\"><span style=\\"background:white\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><strong><span style=\\"font-size:12.0pt\\"><span style=\\"font-family:&quot;Times New Roman&quot;,serif\\">\\u0423\\u0441\\u043b\\u043e\\u0432\\u0438\\u044f:</span></span></strong></span></span></span></span></p><ul><li><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:12.0pt\\"><span><span style=\\"font-family:&quot;Times New Roman&quot;,serif\\">\\u041a\\u043e\\u043d\\u043a\\u0443\\u0440\\u0435\\u043d\\u0442\\u043e\\u0441\\u043f\\u043e\\u0441\\u043e\\u0431\\u043d\\u044b\\u0439 \\u0443\\u0440\\u043e\\u0432\\u0435\\u043d\\u044c \\u0434\\u043e\\u0445\\u043e\\u0434\\u0430 (\\u043e\\u043a\\u043b\\u0430\\u0434+\\u0434\\u043e\\u0441\\u0442\\u043e\\u0439\\u043d\\u044b\\u0435 \\u043f\\u0440\\u0435\\u043c\\u0438\\u0438);</span></span></span></span></span></span></li><li><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:12.0pt\\"><span><span style=\\"font-family:&quot;Times New Roman&quot;,serif\\">\\u041c\\u043e\\u043b\\u043e\\u0434\\u0430\\u044f \\u0438 \\u0434\\u0440\\u0443\\u0436\\u043d\\u0430\\u044f \\u043a\\u043e\\u043c\\u0430\\u043d\\u0434\\u0430;</span></span></span></span></span></span></li><li><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:12.0pt\\"><span><span style=\\"font-family:&quot;Times New Roman&quot;,serif\\">\\u041a\\u043e\\u0440\\u043f\\u043e\\u0440\\u0430\\u0442\\u0438\\u0432\\u043d\\u043e\\u0435 \\u043e\\u0431\\u0443\\u0447\\u0435\\u043d\\u0438\\u0435, \\u043a\\u0443\\u0440\\u0441\\u044b, \\u0442\\u0440\\u0435\\u043d\\u0438\\u043d\\u0433\\u0438;</span></span></span></span></span></span></li><li><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:12.0pt\\"><span><span style=\\"font-family:&quot;Times New Roman&quot;,serif\\">\\u0423\\u044e\\u0442\\u043d\\u044b\\u0439 \\u0438 \\u043a\\u043e\\u043c\\u0444\\u043e\\u0440\\u0442\\u0430\\u0431\\u0435\\u043b\\u044c\\u043d\\u044b\\u0439 \\u043e\\u0444\\u0438\\u0441 \\u0440\\u044f\\u0434\\u043e\\u043c \\u0441 \\u043c. \\u041a\\u0443\\u0442\\u0443\\u0437\\u043e\\u0432\\u0441\\u043a\\u0430\\u044f: \\u0437\\u043e\\u043d\\u044b \\u043e\\u0442\\u0434\\u044b\\u0445\\u0430, \\u0444\\u0438\\u0442\\u043d\\u0435\\u0441-\\u0446\\u0435\\u043d\\u0442\\u0440, \\u043c\\u0430\\u0441\\u0441\\u0430\\u0436\\u043d\\u044b\\u0435 \\u043a\\u0440\\u0435\\u0441\\u043b\\u0430, \\u043f\\u043e\\u0434\\u0437\\u0435\\u043c\\u043d\\u0430\\u044f \\u043f\\u0430\\u0440\\u043a\\u043e\\u0432\\u043a\\u0430;</span></span></span></span></span></span></li><li><span style=\\"font-size:11pt\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span style=\\"font-size:12.0pt\\"><span><span style=\\"font-family:&quot;Times New Roman&quot;,serif\\">\\u0414\\u041c\\u0421, \\u0441\\u0442\\u0440\\u0430\\u0445\\u043e\\u0432\\u0430\\u043d\\u0438\\u0435 \\u043e\\u0442 \\u043d\\u0435\\u0441\\u0447\\u0430\\u0441\\u0442\\u043d\\u044b\\u0445 \\u0441\\u043b\\u0443\\u0447\\u0430\\u0435\\u0432, \\u0441\\u043e\\u0446\\u0438\\u0430\\u043b\\u044c\\u043d\\u044b\\u0435 \\u0433\\u0430\\u0440\\u0430\\u043d\\u0442\\u0438\\u0438, \\u043a\\u043e\\u0440\\u043f\\u043e\\u0440\\u0430\\u0442\\u0438\\u0432\\u043d\\u044b\\u0435 \\u043c\\u0435\\u0440\\u043e\\u043f\\u0440\\u0438\\u044f\\u0442\\u0438\\u044f.</span></span></span></span></span></span></li></ul>", "header": "<p><span style=\\"font-size:11pt\\"><span style=\\"text-autospace:none\\"><span><span style=\\"font-family:Calibri,sans-serif\\"><span styl ...

# %% [markdown]
# # Сколько вакансий для аналитика данных с использованием Python?

# %%
query_1 = 'data analyst'
query_2 = 'python'

result = [v 
          for v in vacs 
          if (
              ((query_1.upper() in v['vactitle'].upper())) 
        #    or ((query_1.upper() in v['vacdescription'].upper()))
          )
          and
          (
              ((query_2.upper() in v['vactitle'].upper())) 
        #    or ((query_2.upper() in v['vacdescription'].upper()))
          )
          ]
len(result), result[:2]
# Out:
# (1,
#  [OrderedDict([('id', '384709'),
#                ('created_at', '2021-03-14 09:39:21.854462'),
#                ('updated_at', '2021-03-14 09:39:21.854584'),
#                ('vacid', '1532790'),
#                ('vactitle', 'Data analyst (Python)'),
#                ('vacdescription',
#                 ' Мы предлагаем: Конкурентную заработную платуУютный офис на Кутузовском проспектеСвободную и позитивную атмосферуОплату посещения конференций на Ваш выбор в разумных количествах, прохождения обучений по корпоративной программеСообщество сильных технарей: рядом с Вами работают разработчики business-critical-систем, обслуживающих десятки миллионов пользователей в месяц, дата-инженеры и аналитики, обрабатывающие терабайты данных ежедневноData Analyst (Python), Москва В Data Science команду Малого и Микро Бизнеса требуется Data-аналитик. Мы любим и умеем использовать данные, чтобы создавать принципиально новые сервисы для клиента и улучшать наши внутренние процессы. Мы даем клиентам рекомендации, помогаем менеджерам лучше понимать клиентов, оптимизируем процессы, создаем витрины данных и делаем много других задач, связанных с обработкой данных. Новому сотруднику предстоит погрузиться в данные о корпоративных клиентах из огромного множества систем Банка. На основе этих данных нужно будет выдвигать и проверять гипотезы, помогать владельцам продуктов формировать представление о клиентах и их поведении, изучать бизнес-процессы, строить собственные витрины и дэшборды, презентовать результаты своей работы. Обязательные требованияОпыт работы с даннымиУверенное владение Python. Знакомство с Python-стеком для обработки и визуализации данных (pandas, numpy, matplotlib, seaborn)Умение выдвигать и проверять гипотезыБазовые навыки разработки ПО (Git, ООП)Уверенное владение SQLБудет плюсомОпыт работы аналитиком в IT-компанииОпыт работы в консалтинге (Big4, IT-консалтинг)Computer science-бекграундИнтерес к машинному обучениюОпыт работы с BI-инструментами (Qlik Sense, Power BI)Знакомство с Big Data-стеком (Hadoop, Spark) О нашем стекеВся работа ведётся на Python. Прототипируем в jupyter-тетрадках, затем переносим код в PyCharm-проектыБольшинство данных находится на Hadoop-кластере, работа с которым организована через SparkВ качестве BI-инструмента используем Qlik Sense  Data Analyst (Python), Москва В Data Science команду Малого и Микро Бизнеса требуется Data-аналитик. Мы любим и умеем использовать данные, чтобы создавать принципиально новые сервисы для клиента и улучшать наши внутренние процессы. Мы даем клиентам рекомендации, помогаем менеджерам лучше понимать клиентов, оптимизируем процессы, создаем витрины данных и делаем много других задач, связанных с обработкой данных. Новому сотруднику предстоит погрузиться в данные о корпоративных клиентах из огромного множества систем Банка. На основе этих данных нужно будет выдвигать и проверять гипотезы, помогать владельцам продуктов формировать представление о клиентах и их поведении, изучать бизнес-процессы, строить собственные витрины и дэшборды, презентовать результаты своей работы. Обязательные требованияОпыт работы с даннымиУверенное владение Python. Знакомство с Python-стеком для обработки и визуализации данных (pandas, numpy, matplotlib, seaborn)Умение выдвигать и проверять гипотезыБазовые навыки разработки ПО (Git, ООП)Уверенное владение SQLБудет плюсомОпыт работы аналитиком в IT-компанииОпыт работы в консалтинге (Big4, IT-консалтинг)Computer science-бекграундИнтерес к машинному обучениюОпыт работы с BI-инструментами (Qlik Sense, Power BI)Знакомство с Big Data-стеком (Hadoop, Spark) О нашем стекеВся работа ведётся на Python. Прототипируем в jupyter-тетрадках, затем переносим код в PyCharm-проектыБольшинство данных находится на Hadoop-кластере, работа с которым организована через SparkВ качестве BI-инструмента используем Qlik Sense   Мы предлагаем: Конкурентную заработную платуУютный офис на Кутузовском проспектеСвободную и позитивную атмосферуОплату посещения конференций на Ваш выбор в разумных количествах, прохождения обучений по корпоративной программеСообщество сильных технарей: рядом с Вами работают разработчики business-critical-систем, обслуживающих десятки миллионов пользователей в месяц, дата-инженеры и аналитики, обрабатывающие терабайты данных ежедневно'),
#                ('vacdate', '2021-03-02'),
#                ('vacstatus', 'new'),
#                ('vaclink',
#                 'https://my.sbertalents.ru/#/job-requisition/1532790'),
#                ('vachtml',
#                 '{"title": "Data analyst (Python)", "footer": "<p>&nbsp;</p><p><span style=\\"font-size:12pt\\"><span style=\\"font-family:Calibri,sans-serif\\"><strong>\\u041c\\u044b \\u043f\\u0440\\u0435\\u0434\\u043b\\u0430\\u0433\\u0430\\u0435\\u043c</strong>: </span></span></p><ul><li><span style=\\"font-size:12pt\\"><span style=\\"font-family:Calibri,sans-serif\\">\\u041a\\u043e\\u043d\\u043a\\u0443\\u0440\\u0435\\u043d\\u0442\\u043d\\u0443\\u044e \\u0437\\u0430\\u0440\\u0430\\u0431\\u043e\\u0442\\u043d\\u0443\\u044e \\u043f\\u043b\\u0430\\u0442\\u0443</span></span></li><li><span style=\\"font-size:12pt\\"><span style=\\"font-family:Calibri,sans-serif\\">\\u0423\\u044e\\u0442\\u043d\\u044b\\u0439 \\u043e\\u0444\\u0438\\u0441 \\u043d\\u0430 \\u041a\\u0443\\u0442\\u0443\\u0437\\u043e\\u0432\\u0441\\u043a\\u043e\\u043c \\u043f\\u0440\\u043e\\u0441\\u043f\\u0435\\u043a\\u0442\\u0435</span></span></li><li><span style=\\"font-size:12pt\\"><span style=\\"font-family:Calibri,sans-serif\\">\\u0421\\u0432\\u043e\\u0431\\u043e\\u0434\\u043d\\u0443\\u044e \\u0438 \\u043f\\u043e\\u0437\\u0438\\u0442\\u0438\\u0432\\u043d\\u0443\\u044e \\u0430\\u0442\\u043c\\u043e\\u0441\\u0444\\u0435\\u0440\\u0443</span></span></li><li><span style=\\"font-size:12pt\\"><span style=\\"font-family:Calibri,sans-serif\\">\\u041e\\u043f\\u043b\\u0430\\u0442\\u0443 \\u043f\\u043e\\u0441\\u0435\\u0449\\u0435\\u043d\\u0438\\u044f \\u043a\\u043e\\u043d\\u0444\\u0435\\u0440\\u0435\\u043d\\u0446\\u0438\\u0439 \\u043d\\u0430 \\u0412\\u0430\\u0448 \\u0432\\u044b\\u0431\\u043e\\u0440 \\u0432 \\u0440\\u0430\\u0437\\u0443\\u043c\\u043d\\u044b\\u0445 \\u043a\\u043e\\u043b\\u0438\\u0